# %% [markdown]
# # Python Ezan Modülü: Python Adhan Module
#
# 1. https://github.com/WhiteSymmetry/ezan
# 2. https://pypi.org/project/ezan/
# 3. https://anaconda.org/channels/bilgi/packages/ezan/overview
# 4. https://prefix.dev/channels/bilgi/packages/ezan
# 5. Kullanım Klavuzu: User Manual: https://github.com/WhiteSymmetry/ezan/blob/main/notebook/ezan.ipynb

# %%
#pip install -U ezan astropy pytz requests

# %%
import pytz
print(' '.join(pytz.all_timezones))
# Out:
# Africa/Abidjan Africa/Accra Africa/Addis_Ababa Africa/Algiers Africa/Asmara Africa/Asmera Africa/Bamako Africa/Bangui Africa/Banjul Africa/Bissau Africa/Blantyre Africa/Brazzaville Africa/Bujumbura Africa/Cairo Africa/Casablanca Africa/Ceuta Africa/Conakry Africa/Dakar Africa/Dar_es_Salaam Africa/Djibouti Africa/Douala Africa/El_Aaiun Africa/Freetown Africa/Gaborone Africa/Harare Africa/Johannesburg Africa/Juba Africa/Kampala Africa/Khartoum Africa/Kigali Africa/Kinshasa Africa/Lagos Africa/Libreville Africa/Lome Africa/Luanda Africa/Lubumbashi Africa/Lusaka Africa/Malabo Africa/Maputo Africa/Maseru Africa/Mbabane Africa/Mogadishu Africa/Monrovia Africa/Nairobi Africa/Ndjamena Africa/Niamey Africa/Nouakchott Africa/Ouagadougou Africa/Porto-Novo Africa/Sao_Tome Africa/Timbuktu Africa/Tripoli Africa/Tunis Africa/Windhoek America/Adak America/Anchorage America/Anguilla America/Antigua America/Araguaina America/Argentina/Buenos_Aires America/Argentina/Catamarca America/Argentina/ComodRiv
# ...

# %%
import pytz

print(' '.join(pytz.country_timezones['tr'])) # Ükle kodu: Country code: Türkiye (tr)
# tz: timezone: Saat Dilimi: Europe/Istanbul
# Out:
# Europe/Istanbul

# %% [markdown]
# # Sistem/System:
#
# Varsayılan sizin konum bilgilerinizi sisteminiz izin verirse otomatik olarak seçer ve yerel ezan bilgilerini verir.
# Eğer sisteminiz izin vermez ise varsayılan olarak İstanbul'un ezan bilgilerini verir.
#
# ✅ Sistem tarihi alındı: 2026-02-21
#
# ✅ Konum bilgisi alındı: Istanbul, Türkiye
#
# 📍 Enlem: 41.****, Boylam: 28.****
#
# ========================================
#
# 🌙 NAMAZ VAKİTLERİ - 2026-02-21
#
# 📍 Konum: Enlem 41.0***, Boylam 28.****
#
# 🕒 Zaman Dilimi: Europe/Istanbul
#
# ========================================
#
# 🌅 İmsak/Fecr/Fajr(فجر)... 06:18:56
#
#    Astronomik şafak (-18.0°) – Diyânet imsak vakti?
#
# Not: Tam -18° aslında 0° ekvator enlemi için geçerlidir
#
# ☀️ Güneşin Doğuşu/Sunrise(شروق) 07:50:35
#
#    Güneş ufuk çizgisinde (-0.833°)
#
# 🌞 Öğle Namazı/Dhuhr/Zhuhr(ظهر) 13:22:29
#
#    Güneş zenitten 2.0° aşağıda (Hanefi)
#
# 🌇 İkindi - Standart/Asr(عصر) 16:22:29
#
#    Gölge boyu = 1 cisim boyu
#
# 🌆 İkindi - Hanefi/Asr(عصر) 17:02:55
#
#    Gölge boyu = 2 cisim boyu
#
# 🌄 Akşam Namazı/Maghrib(مغرب) 18:45:33
#
#    Güneş batışı (-0.833°)
#
# 🌙 Yatsı Namazı/Isha(عشاء) 20:12:01
#
#    Diyanet yatsı vakti (-17.0°)
#
# Astronomik şafak ise -18.0°
#
#
# 📊 ASTRONOMİK BİLGİLER
#
#    Güneş Deklinasyonu: -10.58°
#
#    Yılın Günü: 52
#
#    Güneş Tepe Noktası: 13:07:29
#
# 🕋 KIBLE BİLGİLERİ
#
#    Kıble Açısı (Kuzeyden saat yönünde): 151.55°
#
#    Kıble Saati 1: 11:43:07 (Güneş tam kıble yönünde)

# %%
from ezan import print_prayer_times, get_user_location_and_date

lat, lon, tz, date = get_user_location_and_date()
print_prayer_times(lat, lon, tz, date)
# Out:
# ✅ Sistem tarihi alındı: 2026-02-21
# ✅ Konum bilgisi alındı: Istanbul, Türkiye
# 📍 Enlem: 41.0108, Boylam: 28.9482
#
# ...
# 🌙 NAMAZ VAKİTLERİ - 2026-02-21
# 📍 Konum: Enlem 41.0108, Boylam 28.9482
# 🕒 Zaman Dilimi: Europe/Istanbul
# ...
# 🌅 İmsak/Fecr/Fajr(فجر)... 06:18:56
#    Astronomik şafak (-18.0°) – Diyânet imsak vakti?
# Not: Tam -18° aslında 0° ekvator enlemi için geçerlidir
# ☀️ Güneşin Doğuşu/Sunrise(شروق) 07:50:35
#    Güneş ufuk çizgisinde (-0.833°)
# 🌞 Öğle Namazı/Dhuhr/Zhuhr(ظهر) 13:22:29
#    Güneş zenitten 2.0° aşağıda (Hanefi)
# 🌇 İkindi - Standart/Asr(عصر) 16:22:29
#    Gölge boyu = 1 cisim boyu
# 🌆 İkindi - Hanefi/Asr(عصر) 17:02:55
#    Gölge boyu = 2 cisim boyu
# 🌄 Akşam Namazı/Maghrib(مغرب) 18:45:33
#    Güneş batışı (-0.833°)
# 🌙 Yatsı Namazı/Isha(عشاء) 20:12:01
#    Diyanet yatsı vakti (-17.0°)
# Astronomik şafak ise -18.0°
#
# 📊 ASTRONOMİK BİLGİLER
#    Güneş Deklinasyonu: -10.58°
#    Yılın Günü: 52
#    Güneş Tepe Noktası: 13:07:29
#
# 🕋 KIBLE BİLGİLERİ
# ...

# %%
import sys
sys.path.append("/home/mk/conda/envs/s11/lib/python3.11/site-packages/ezan/")   # ezan klasörünün üst dizini
import ezan

# %% [markdown]
# # Doğrudan menülü çalıştırma:
#
# ezan.py'ın sisteminizdeki yolu:
#
# /home/kullanıcıadı/conda/envs/***/lib/python3.11/site-packages/ezan/ezan.py
#
# 🌙🕌 Kod İle Namaz/Salât Vakitleri Hesaplayıcısı
#
# Not: Kod ile hesaplandığından yerel takvimlerden küçük sapmalar olabilir.
#
# ==========================================
#
# Seçenekler:
#
# 1 - Otomatik konum ve bugünün tarihi
#
# 2 - Farklı giriş seçenekleri (manuel)
#
# 3 - Çıkış
#
# Seçiminiz (1-3):  1
#
# ✅ Sistem tarihi alındı: 2026-02-21
#
# ✅ Konum bilgisi alındı: Istanbul, Türkiye
#
# 📍 Enlem: 41.****, Boylam: 28.****
#
# ========================================
#
# 🌙 NAMAZ VAKİTLERİ - 2026-02-21
#
# 📍 Konum: Enlem 41.****, Boylam 28.****
#
# 🕒 Zaman Dilimi: Europe/Istanbul
#
# ========================================
#
# 🌅 İmsak/Fecr/Fajr(فجر)... 06:18:56
#
#    Astronomik şafak (-18.0°) – Diyânet imsak vakti?
#
# Not: Tam -18° aslında 0° ekvator enlemi için geçerlidir
#
# ☀️ Güneşin Doğuşu/Sunrise(شروق) 07:50:35
#
#    Güneş ufuk çizgisinde (-0.833°)
#
# 🌞 Öğle Namazı/Dhuhr/Zhuhr(ظهر) 13:22:29
#
#    Güneş zenitten 2.0° aşağıda (Hanefi)
#
# 🌇 İkindi - Standart/Asr(عصر) 16:22:29
#
#    Gölge boyu = 1 cisim boyu
#
# 🌆 İkindi - Hanefi/Asr(عصر) 17:02:55
#
#    Gölge boyu = 2 cisim boyu
#
# 🌄 Akşam Namazı/Maghrib(مغرب) 18:45:33
#
#    Güneş batışı (-0.833°)
#
# 🌙 Yatsı Namazı/Isha(عشاء) 20:12:01
#
#    Diyanet yatsı vakti (-17.0°)
#
# Astronomik şafak ise -18.0°
#
# 📊 ASTRONOMİK BİLGİLER
#
#    Güneş Deklinasyonu: -10.58°
#
#    Yılın Günü: 52
#
#    Güneş Tepe Noktası: 13:07:29
#
# 🕋 KIBLE BİLGİLERİ
#
#    Kıble Açısı (Kuzeyden saat yönünde): 151.55°
#
#    Kıble Saati 1: 11:43:07 (Güneş tam kıble yönünde)
#
# ======================================
#
# Seçenekler:
#
# 1 - Otomatik konum ve bugünün tarihi
#
# 2 - Farklı giriş seçenekleri (manuel)
#
# 3 - Çıkış
#
# Seçiminiz (1-3):  3
#
# 👋 Allāh (c.c)'ne emânet olunuz (May Allah (swt) protect you!)!
#
# 👋 في أمان الله (سبحانه وتعالى)!
#
# 👋 Fī amānillāh subḥānahu wa ta'ālā!
#
# 👋 Maşâllāh (Maşâe Allāh)!

# %%
# %run -i /home/mk/conda/envs/s11/lib/python3.11/site-packages/ezan/ezan.py
# Out:
# 🌙🕌 Kod İle Namaz/Salât Vakitleri Hesaplayıcısı
# Not: Kod ile hesaplandığından yerel takvimlerden küçük sapmalar olabilir.
# ...
#
# Seçenekler:
# 1 - Otomatik konum ve bugünün tarihi
# 2 - Farklı giriş seçenekleri (manuel)
# 3 - Çıkış
# Seçiminiz (1-3):  3
# 👋 Allāh (c.c)'ne emânet olunuz (May Allah (swt) protect you!)!
# 👋 في أمان الله (سبحانه وتعالى)!
# 👋 Fī amānillāh subḥānahu wa ta'ālā!
# 👋 Maşâllāh (Maşâe Allāh)!

# %% [markdown]
# # İstediğiniz enlem, boylam, Saat dilimi seçebilirsiniz:
#
# lat: Latitude: Enlem
#
# lon: Longitude: Boylam
#
# tz: timezone: Saat dilimi
#
# tarih: date
#
# tarih = datetime.date(tıl/year, ay/month, gün/day)

# %%
from ezan import print_prayer_times
import datetime

# Kendi değerlerinizi girin
lat = 41.0          # enlem (derece)
lon = 29.0          # boylam (derece)
tz = 'Europe/Istanbul'   # zaman dilimi (Europe/Istanbul, Asia/Damascus vb.)
tarih = datetime.date(2026, 2, 20)   # tarih: yıl, ay, gün

# Hesaplamayı çalıştır
print_prayer_times(lat, lon, tz, tarih)
# Out:
# ...
# 🌙 NAMAZ VAKİTLERİ - 2026-02-20
# 📍 Konum: Enlem 41.0000, Boylam 29.0000
# 🕒 Zaman Dilimi: Europe/Istanbul
# ...
# 🌅 İmsak/Fecr/Fajr(فجر)... 06:20:03
#    Astronomik şafak (-18.0°) – Diyânet imsak vakti?
# Not: Tam -18° aslında 0° ekvator enlemi için geçerlidir
# ☀️ Güneşin Doğuşu/Sunrise(شروق) 07:51:47
#    Güneş ufuk çizgisinde (-0.833°)
# 🌞 Öğle Namazı/Dhuhr/Zhuhr(ظهر) 13:22:29
#    Güneş zenitten 2.0° aşağıda (Hanefi)
# 🌇 İkindi - Standart/Asr(عصر) 16:22:29
#    Gölge boyu = 1 cisim boyu
# 🌆 İkindi - Hanefi/Asr(عصر) 17:01:38
#    Gölge boyu = 2 cisim boyu
# 🌄 Akşam Namazı/Maghrib(مغرب) 18:44:10
#    Güneş batışı (-0.833°)
# 🌙 Yatsı Namazı/Isha(عشاء) 20:10:41
#    Diyanet yatsı vakti (-17.0°)
# Astronomik şafak ise -18.0°
#
# 📊 ASTRONOMİK BİLGİLER
#    Güneş Deklinasyonu: -10.94°
#    Yılın Günü: 51
#    Güneş Tepe Noktası: 13:07:29
#
# 🕋 KIBLE BİLGİLERİ
#    Kıble Açısı (Kuzeyden saat yönünde): 151.66°
#    Kıble Saati 1: 11:42:51 (Güneş tam kıble yönünde)
# ...
